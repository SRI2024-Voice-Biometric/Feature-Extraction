# %%
import numpy as np
from scipy.signal import lfilter
from scipy.signal.windows import hann
from scipy.linalg import toeplitz, solve_toeplitz
from scipy.signal import convolve
import os
import librosa
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
import matplotlib.pyplot as plt
import math
import gc
from IPython.display import clear_output
import tensorflow.keras.layers as tfl
import tensorflow as tf
from keras.callbacks import ReduceLROnPlateau

# %%
def lpc(x, order, regularization=1e-12):
    R = np.correlate(x, x, mode='full')[len(x)-1:]
    R = R[:order+1]
    R[0] += regularization  # Apply regularization
    coeff = solve_toeplitz((R[:order], R[:order]), -R[1:])
    
    if coeff[0] == 0:  # Ensure the first coefficient is not zero
        coeff[0] = 1e-10  # Add a small value to avoid issues
    
    return coeff

# %%
def gfmiaif_pulse(s_gvl, iterations=1, nv=12, ng=3, enc_size=16, d=0.99, win=None):
    if win is None:
        win = hann(len(s_gvl))
    
    Lpf = nv + 1
    x_gvl = np.concatenate((np.linspace(-s_gvl[0], s_gvl[0], Lpf), s_gvl))
    idx_pf = slice(Lpf, len(x_gvl))
    
    al = [1, -d]
    s_gv = lfilter([1], al, s_gvl)
    x_gv = lfilter([1], al, x_gvl)
    
    ag1 = lpc(s_gv * win, 1)
    
    for _ in range(ng - 1):
        x_v1x = lfilter(ag1, [1], x_gv)
        s_v1x = x_v1x[idx_pf]
        ag1x = lpc(s_v1x * win, 1)
        ag1 = np.convolve(ag1, ag1x)
    
    x_v1 = lfilter(ag1, [1], x_gv)
    s_v1 = x_v1[idx_pf]
    av1 = lpc(s_v1 * win, nv)
    
    for _ in range(iterations):
        x_g1 = lfilter(av1, [1], x_gv)
        s_g1 = x_g1[idx_pf]
        ag = lpc(s_g1 * win, ng)
    
        x_v = lfilter(ag, [1], x_gv)
        s_v = x_v[idx_pf]
        av1 = lpc(s_v * win, nv)
        
    glottal_pulse = lfilter(av1, [1], s_gvl)
    vt_pulse = lfilter(ag, [1], s_gvl)
    
    return vt_pulse,glottal_pulse

# %%
def generate_spec(data_folder,create_folder,num_speakers=5,num_frames=100,frame_length_msec=30,sr=44100,verbose=True):
    
    ori_folder = os.path.join(create_folder, "original")
    vt_folder = os.path.join(create_folder, "vocal_tract")
    glot_folder = os.path.join(create_folder, "glottal")
    
    total_speaker = 0
    for speaker in os.listdir(data_folder):
        ori_folder_speaker = os.path.join(ori_folder, speaker)
        vt_folder_speaker = os.path.join(vt_folder, speaker)
        glot_folder_speaker = os.path.join(glot_folder, speaker)
        os.makedirs(ori_folder_speaker, exist_ok=True)
        os.makedirs(vt_folder_speaker, exist_ok=True)
        os.makedirs(glot_folder_speaker, exist_ok=True)
        
        total_time_data=num_frames*frame_length_msec
        curr_time=0
        
        y=[]
        wav_files=os.listdir(os.path.join(data_folder, speaker))
        idx=0
        while curr_time<total_time_data:
            if wav_files[idx].endswith(".wav"):
                wav_file_path = os.path.join(data_folder, speaker, wav_files[idx])

                y_curr, sr = librosa.load(wav_file_path, sr=sr)
                y.extend(y_curr)
                
                curr_time+=60000
                idx+=1
                
        del wav_files

        frame_length_samples=frame_length_msec*sr//1000
        frames = librosa.util.frame(y, frame_length=frame_length_samples, hop_length=frame_length_samples).T
        frames=frames[:num_frames]
#         print(frames)
        
        del y

        for num,frame in enumerate(frames):
            vt,glot=gfmiaif_pulse(frame)
            window=hann(len(frame))
            frame_windowed = frame * window
            glot_windowed = glot * window
            vt_windowed = vt * window

            del vt,glot
            
            plt.figure(figsize=(5, 5))
            ax = plt.axes()
            ax.set_axis_off()
            plt.set_cmap('hot')
            amp=np.abs(librosa.stft(frame_windowed))
            D = librosa.amplitude_to_db(amp, ref=np.max)
            librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
            output_path = os.path.join(ori_folder_speaker, "ori"+str(num+1) + ".png")
            plt.savefig(output_path, bbox_inches='tight', transparent=True, pad_inches=0.0)
            plt.close('all')
        
            plt.figure(figsize=(5, 5))
            ax = plt.axes()
            ax.set_axis_off()
            plt.set_cmap('hot')
            amp=np.abs(librosa.stft(vt_windowed))
            D = librosa.amplitude_to_db(amp, ref=np.max)
            librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
            output_path = os.path.join(vt_folder_speaker, "vt"+str(num+1) + ".png")
            plt.savefig(output_path, bbox_inches='tight', transparent=True, pad_inches=0.0)
            plt.close('all')
            
            plt.figure(figsize=(5, 5))
            ax = plt.axes()
            ax.set_axis_off()
            plt.set_cmap('hot')
            amp=np.abs(librosa.stft(glot_windowed))
            D = librosa.amplitude_to_db(amp, ref=np.max)
            librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
            output_path = os.path.join(glot_folder_speaker, "glot"+str(num+1) + ".png")
            plt.savefig(output_path, bbox_inches='tight', transparent=True, pad_inches=0.0)
            plt.close('all')
            del D,ax,output_path
            gc.collect()

        del frames
                        
        total_speaker += 1
        if total_speaker != 0 and total_speaker % 1 == 0 and verbose:
            print(f"{total_speaker} speakers completed.\n")

        if total_speaker == num_speakers:
            break

# %%
num_speakers=5
frame_length_msec=50
num_frames=100
data_folder="/kaggle/input/speaker-recognition-audio-dataset/50_speakers_audio_data"
create_folder="/kaggle/working/"

# %%
generate_spec(data_folder,create_folder,num_speakers,num_frames,frame_length_msec)
# Out:
# [src/libmpg123/layer3.c:INT123_do_layer3():1771] error: part2_3_length (1600) too large for available bit count (1568)
# 1 speakers completed.
#
# 2 speakers completed.
#
# 3 speakers completed.
#
# 4 speakers completed.
#
# 5 speakers completed.

# %%
from PIL import Image

dataset_path_ori="/kaggle/working/original"
dataset_path_vt="/kaggle/working/vocal_tract"
dataset_path_glot="/kaggle/working/glottal"
folders=os.listdir(dataset_path_ori)

# Initializing training and test dataset
X_train=[[],[],[]]
y_train=[[],[],[]]
X_test=[[],[],[]]
y_test=[[],[],[]]

# Split the dataset into training and test set.
num=np.random.rand(num_frames*num_speakers)
mask=num<0.2
split=mask.astype(int)

for dirs in folders:
    i=0
    for img in os.listdir(os.path.join(dataset_path_ori,dirs)):
        image=Image.open(os.path.join(dataset_path_ori,dirs,img))
        new_img=image.resize((200,200))
        tmp_array=np.array(new_img)/255.
        if split[i]==0:
            X_train[0].append(tmp_array)
            y_train[0].append(str(dirs))
        else:
            X_test[0].append(tmp_array)
            y_test[0].append(str(dirs))
            
        i+=1
        
    i=0    
    for img in os.listdir(os.path.join(dataset_path_vt,dirs)):
        image=Image.open(os.path.join(dataset_path_vt,dirs,img))
        new_img=image.resize((200,200))
        tmp_array=np.array(new_img)/255.
        if split[i]==0:
            X_train[1].append(tmp_array)
            y_train[1].append(str(dirs))
        else:
            X_test[1].append(tmp_array)
            y_test[1].append(str(dirs))
            
        i+=1
            
    i=0
    for img in os.listdir(os.path.join(dataset_path_glot,dirs)):
        image=Image.open(os.path.join(dataset_path_glot,dirs,img))
        new_img=image.resize((200,200))
        tmp_array=np.array(new_img)/255.
        if split[i]==0:
            X_train[2].append(tmp_array)
            y_train[2].append(str(dirs))
        else:
            X_test[2].append(tmp_array)
            y_test[2].append(str(dirs))
        
        i+=1

# %%
dict={}
i=0
for val in folders:
    dict[val]=i
    i=i+1

dict
# Out:
# {'Speaker0043': 0,
#  'Speaker_0014': 1,
#  'Speaker0047': 2,
#  'Speaker_0009': 3,
#  'Speaker0029': 4}

# %%
i=0
for _ in y_train[0]:
    y_train[0][i]=dict[y_train[0][i]]
    i=i+1

i=0
for _ in y_test[0]:
    y_test[0][i]=dict[y_test[0][i]]
    i=i+1
    
i=0
for _ in y_train[1]:
    y_train[1][i]=dict[y_train[1][i]]
    i=i+1

i=0
for _ in y_test[1]:
    y_test[1][i]=dict[y_test[1][i]]
    i=i+1
    
i=0
for _ in y_train[2]:
    y_train[2][i]=dict[y_train[2][i]]
    i=i+1

i=0
for _ in y_test[2]:
    y_test[2][i]=dict[y_test[2][i]]
    i=i+1

# %%
def convolutional_model(input_shape,output_shape):
    input_img = tf.keras.Input(shape=input_shape)
    Z1=tfl.Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding='same')(input_img)
    A1=tfl.ReLU()(Z1)
    P1=tfl.MaxPool2D(pool_size=(4,4),padding='same')(A1)
    Z2=tfl.Conv2D(filters=64,kernel_size=(2,2),strides=(1,1),padding='same')(P1)
    A2=tfl.ReLU()(Z2)
    P2=tfl.MaxPool2D(pool_size=(4,4),padding='same')(A2)
    Z3=tfl.Conv2D(filters=128,kernel_size=(2,2),strides=(1,1),padding='same')(P2)
    A3=tfl.ReLU()(Z3)
    P3=tfl.MaxPool2D(pool_size=(4,4),padding='same')(A3)
    F=tfl.Flatten()(P3)
    D1=tfl.Dense(128)(F)
    DP1=tfl.Dropout(0.5)(D1)
    
    outputs=tfl.Dense(output_shape,activation='softmax')(DP1)
    
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model_ori = convolutional_model((200, 200, 4),num_speakers)
conv_model_ori.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 711ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9727 - val_loss: 0.1115 - learning_rate: 5.0000e-04
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 625ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9455 - val_loss: 0.1295 - learning_rate: 5.0000e-04
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 629ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9727 - val_loss: 0.1162 - learning_rate: 5.0000e-04
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 589ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9727 - val_loss: 0.1127 - learning_rate: 5.0000e-04
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 662ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9636 - val_loss: 0.1252 - learning_rate: 5.0000e-04
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 601ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9727 - val_loss: 0.1169 - learning_rate: 5.0000e-04
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 599ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9727 - val_loss: 0.1125 - learning_rate: 2.5000e-04
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 593ms/step - accuracy: 0.9985 - loss: 0.0048 - val_accuracy: 0.9727 - val_loss: 0.1120 - learning_rate: 2.5000e-04
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 659ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9727 - val_loss: 0.1123 - learning_rate: 2.5000e-04
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 604ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9727 - val_loss: 0.1137 - learning_rate: 2.5000e-04
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 583ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9727 - val_loss: 0.1124 - learning_rate: 2.5000e-04
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 650ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9636 - val_loss: 0.1178 - learning_rate: 2.5000e-04
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 606ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9727 - val_loss: 0.1157 - learning_rate: 2.5000e-04
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 600ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9727 - val_loss: 0.1160 - learning_rate: 2.5000e-04
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 651ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9727 - val_loss: 0.1120 - learning_rate: 2.5000e-04
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 664ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9727 - val_loss: 0.1200 - learning_rate: 2.5000e-04
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 556ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9727 - val_loss: 0.1194 - learning_rate: 1.2500e-04
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 571ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9727 - val_loss: 0.1182 - learning_rate: 1.2500e-04
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 552ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9727 - val_loss: 0.1185 - learning_rate: 1.2500e-04
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 601ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9727 - val_loss: 0.1181 - learning_rate: 1.2500e-04
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 558ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9727 - val_loss: 0.1180 - learning_rate: 1.2500e-04
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 571ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9727 - val_loss: 0.1194 - learning_rate: 1.2500e-04
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9727 - val_loss: 0.1210 - learning_rate: 1.2500e-04
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 603ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9727 - val_loss: 0.1212 - learning_rate: 1.2500e-04
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 550ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9727 - val_loss: 0.1205 - learning_rate: 1.2500e-04
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 546ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9727 - val_loss: 0.1206 - learning_rate: 1.2500e-04
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 550ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9727 - val_loss: 0.1206 - learning_rate: 6.2500e-05
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 583ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9727 - val_loss: 0.1183 - learning_rate: 6.2500e-05
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 554ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9727 - val_loss: 0.1175 - learning_rate: 6.2500e-05
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 552ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9727 - val_loss: 0.1173 - learning_rate: 6.2500e-05
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9727 - val_loss: 0.1170 - learning_rate: 6.2500e-05
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 595ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9727 - val_loss: 0.1174 - learning_rate: 6.2500e-05
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 552ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9727 - val_loss: 0.1184 - learning_rate: 6.2500e-05
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 563ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9727 - val_loss: 0.1176 - learning_rate: 6.2500e-05
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 553ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9727 - val_loss: 0.1164 - learning_rate: 6.2500e-05
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 600ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9727 - val_loss: 0.1164 - learning_rate: 6.2500e-05
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 548ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9727 - val_loss: 0.1168 - learning_rate: 3.1250e-05
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 552ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9727 - val_loss: 0.1173 - learning_rate: 3.1250e-05
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 552ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9727 - val_loss: 0.1173 - learning_rate: 3.1250e-05
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 544ms/step - accuracy: 1.0000 - loss: 8.3461e-04 - val_accuracy: 0.9727 - val_loss: 0.1172 - learning_rate: 3.1250e-05
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 544ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9727 - val_loss: 0.1171 - learning_rate: 3.1250e-05
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 557ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9727 - val_loss: 0.1177 - learning_rate: 3.1250e-05
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 601ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9727 - val_loss: 0.1187 - learning_rate: 3.1250e-05
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 548ms/step - accuracy: 1.0000 - loss: 8.2122e-04 - val_accuracy: 0.9727 - val_loss: 0.1193 - learning_rate: 3.1250e-05
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 547ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9727 - val_loss: 0.1199 - learning_rate: 3.1250e-05
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 551ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9727 - val_loss: 0.1195 - learning_rate: 3.1250e-05
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 604ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9727 - val_loss: 0.1193 - learning_rate: 1.5625e-05
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 560ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9727 - val_loss: 0.1192 - learning_rate: 1.5625e-05
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 559ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9727 - val_loss: 0.1199 - learning_rate: 1.5625e-05
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9727 - val_loss: 0.1201 - learning_rate: 1.5625e-05
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 610ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9727 - val_loss: 0.1198 - learning_rate: 1.5625e-05
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9727 - val_loss: 0.1196 - learning_rate: 1.5625e-05
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 549ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9727 - val_loss: 0.1196 - learning_rate: 1.5625e-05
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 557ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9727 - val_loss: 0.1196 - learning_rate: 1.5625e-05
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 567ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9727 - val_loss: 0.1194 - learning_rate: 1.5625e-05
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 554ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9727 - val_loss: 0.1187 - learning_rate: 1.5625e-05
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 547ms/step - accuracy: 1.0000 - loss: 6.5003e-04 - val_accuracy: 0.9727 - val_loss: 0.1187 - learning_rate: 1.0000e-05

# %%
conv_model_glot = convolutional_model((200, 200, 4),num_speakers)
conv_model_glot.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.00001)
history_glot = conv_model_glot.fit(np.array(X_train[2]),np.array(y_train[2]), batch_size=32, epochs=75, validation_data=(np.array(X_test[2]),np.array(y_test[2])),callbacks=(reduce_lr))
# Out:
# Epoch 1/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 583ms/step - accuracy: 0.3024 - loss: 1.5684 - val_accuracy: 0.6364 - val_loss: 1.1732 - learning_rate: 0.0010
# Epoch 2/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 549ms/step - accuracy: 0.6013 - loss: 1.0738 - val_accuracy: 0.7182 - val_loss: 0.8435 - learning_rate: 0.0010
# Epoch 3/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 551ms/step - accuracy: 0.6635 - loss: 0.8436 - val_accuracy: 0.7182 - val_loss: 0.6368 - learning_rate: 0.0010
# Epoch 4/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 556ms/step - accuracy: 0.7800 - loss: 0.6410 - val_accuracy: 0.7818 - val_loss: 0.4824 - learning_rate: 0.0010
# Epoch 5/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 552ms/step - accuracy: 0.8053 - loss: 0.5872 - val_accuracy: 0.9273 - val_loss: 0.3062 - learning_rate: 0.0010
# Epoch 6/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 611ms/step - accuracy: 0.8785 - loss: 0.3701 - val_accuracy: 0.9455 - val_loss: 0.2641 - learning_rate: 0.0010
# Epoch 7/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 554ms/step - accuracy: 0.8805 - loss: 0.3033 - val_accuracy: 0.9000 - val_loss: 0.3076 - learning_rate: 0.0010
# Epoch 8/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 557ms/step - accuracy: 0.9212 - loss: 0.2268 - val_accuracy: 0.9545 - val_loss: 0.1585 - learning_rate: 0.0010
# Epoch 9/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s
75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 558ms/step - accuracy: 0.9917 - loss: 0.0247 - val_accuracy: 0.9545 - val_loss: 0.1477 - learning_rate: 0.0010
# Epoch 29/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 606ms/step - accuracy: 0.9927 - loss: 0.0187 - val_accuracy: 0.9545 - val_loss: 0.1559 - learning_rate: 5.0000e-04
# Epoch 30/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - accuracy: 0.9968 - loss: 0.0102 - val_accuracy: 0.9545 - val_loss: 0.1510 - learning_rate: 5.0000e-04
# Epoch 31/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 545ms/step - accuracy: 0.9985 - loss: 0.0045 - val_accuracy: 0.9545 - val_loss: 0.1461 - learning_rate: 5.0000e-04
# Epoch 32/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 554ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9545 - val_loss: 0.1479 - learning_rate: 5.0000e-04
# Epoch 33/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 602ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9545 - val_loss: 0.1467 - learning_rate: 5.0000e-04
# Epoch 34/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 0.9974 - loss: 0.0071 - val_accuracy: 0.9545 - val_loss: 0.1578 - learning_rate: 5.0000e-04
# Epoch 35/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9545 - val_loss: 0.1507 - learning_rate: 5.0000e-04
# Epoch 36/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 549ms/step - accuracy: 0.9996 - loss: 0.0036 - val_accuracy: 0.9545 - val_loss: 0.1589 - learning_rate: 5.0000e-04
# Epoch 37/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 558ms/step - accuracy: 0.9864 - loss: 0.0309 - val_accuracy: 0.9273 - val_loss: 0.2900 - learning_rate: 5.0000e-04
# Epoch 38/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 558ms/step - accuracy: 0.9882 - loss: 0.0272 - val_accuracy: 0.9545 - val_loss: 0.1887 - learning_rate: 5.0000e-04
# Epoch 39/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 558ms/step - accuracy: 0.9884 - loss: 0.0216 - val_accuracy: 0.9545 - val_loss: 0.1742 - learning_rate: 2.5000e-04
# Epoch 40/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 555ms/step - accuracy: 0.9955 - loss: 0.0083 - val_accuracy: 0.9545 - val_loss: 0.1613 - learning_rate: 2.5000e-04
# Epoch 41/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 602ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9545 - val_loss: 0.1620 - learning_rate: 2.5000e-04
# Epoch 42/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 560ms/step - accuracy: 0.9968 - loss: 0.0071 - val_accuracy: 0.9545 - val_loss: 0.1752 - learning_rate: 2.5000e-04
# Epoch 43/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 551ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9545 - val_loss: 0.1756 - learning_rate: 2.5000e-04
# Epoch 44/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 555ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 0.9545 - val_loss: 0.1761 - learning_rate: 2.5000e-04
# Epoch 45/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 551ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9545 - val_loss: 0.1847 - learning_rate: 2.5000e-04
# Epoch 46/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 555ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9545 - val_loss: 0.1769 - learning_rate: 2.5000e-04
# Epoch 47/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 575ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9545 - val_loss: 0.1714 - learning_rate: 2.5000e-04
# Epoch 48/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 599ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9545 - val_loss: 0.1734 - learning_rate: 2.5000e-04
# Epoch 49/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 604ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9545 - val_loss: 0.1753 - learning_rate: 1.2500e-04
# Epoch 50/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 562ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9545 - val_loss: 0.1757 - learning_rate: 1.2500e-04
# Epoch 51/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 569ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9545 - val_loss: 0.1750 - learning_rate: 1.2500e-04
# Epoch 52/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 625ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9545 - val_loss: 0.1766 - learning_rate: 1.2500e-04
# Epoch 53/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 586ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9545 - val_loss: 0.1780 - learning_rate: 1.2500e-04
# Epoch 54/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 573ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9545 - val_loss: 0.1772 - learning_rate: 1.2500e-04
# Epoch 55/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 561ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9545 - val_loss: 0.1767 - learning_rate: 1.2500e-04
# Epoch 56/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 583ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9545 - val_loss: 0.1757 - learning_rate: 1.2500e-04
# Epoch 57/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 602ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9545 - val_loss: 0.1790 - learning_rate: 1.2500e-04
# Epoch 58/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 596ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9545 - val_loss: 0.1815 - learning_rate: 1.2500e-04
# Epoch 59/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 570ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9545 - val_loss: 0.1805 - learning_rate: 6.2500e-05
# Epoch 60/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 615ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9545 - val_loss: 0.1805 - learning_rate: 6.2500e-05
# Epoch 61/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 580ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9545 - val_loss: 0.1808 - learning_rate: 6.2500e-05
# Epoch 62/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 576ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9545 - val_loss: 0.1805 - learning_rate: 6.2500e-05
# Epoch 63/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 585ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9545 - val_loss: 0.1803 - learning_rate: 6.2500e-05
# Epoch 64/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 606ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9545 - val_loss: 0.1810 - learning_rate: 6.2500e-05
# Epoch 65/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 569ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9545 - val_loss: 0.1815 - learning_rate: 6.2500e-05
# Epoch 66/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 559ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9545 - val_loss: 0.1821 - learning_rate: 6.2500e-05
# Epoch 67/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 616ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9545 - val_loss: 0.1812 - learning_rate: 6.2500e-05
# Epoch 68/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 579ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9545 - val_loss: 0.1807 - learning_rate: 6.2500e-05
# Epoch 69/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 570ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9545 - val_loss: 0.1810 - learning_rate: 3.1250e-05
# Epoch 70/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 566ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9545 - val_loss: 0.1814 - learning_rate: 3.1250e-05
# Epoch 71/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 601ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9545 - val_loss: 0.1815 - learning_rate: 3.1250e-05
# Epoch 72/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9545 - val_loss: 0.1812 - learning_rate: 3.1250e-05
# Epoch 73/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 552ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9545 - val_loss: 0.1819 - learning_rate: 3.1250e-05
# Epoch 74/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 609ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9545 - val_loss: 0.1816 - learning_rate: 3.1250e-05
# Epoch 75/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 547ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9545 - val_loss: 0.1816 - learning_rate: 3.1250e-05

# %%
conv_model_vt = convolutional_model((200, 200, 4),num_speakers)
conv_model_vt.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.00001)
history_vt = conv_model_vt.fit(np.array(X_train[1]),np.array(y_train[1]), batch_size=32, epochs=75, validation_data=(np.array(X_test[1]),np.array(y_test[1])),callbacks=(reduce_lr))
# Out:
# Epoch 1/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 584ms/step - accuracy: 0.3180 - loss: 1.5787 - val_accuracy: 0.7091 - val_loss: 1.1821 - learning_rate: 0.0010
# Epoch 2/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 573ms/step - accuracy: 0.5447 - loss: 1.1134 - val_accuracy: 0.7000 - val_loss: 0.8292 - learning_rate: 0.0010
# Epoch 3/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 542ms/step - accuracy: 0.7037 - loss: 0.7400 - val_accuracy: 0.7636 - val_loss: 0.6987 - learning_rate: 0.0010
# Epoch 4/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 555ms/step - accuracy: 0.7593 - loss: 0.6812 - val_accuracy: 0.7818 - val_loss: 0.5878 - learning_rate: 0.0010
# Epoch 5/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 591ms/step - accuracy: 0.8112 - loss: 0.5624 - val_accuracy: 0.8727 - val_loss: 0.4036 - learning_rate: 0.0010
# Epoch 6/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 551ms/step - accuracy: 0.8843 - loss: 0.3703 - val_accuracy: 0.8909 - val_loss: 0.2885 - learning_rate: 0.0010
# Epoch 7/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - accuracy: 0.9381 - loss: 0.2628 - val_accuracy: 0.8727 - val_loss: 0.3771 - learning_rate: 0.0010
# Epoch 8/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 548ms/step - accuracy: 0.9260 - loss: 0.2101 - val_accuracy: 0.8909 - val_loss: 0.2988 - learning_rate: 0.0010
# Epoch 9/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 599ms/step - accuracy: 0.9203 - loss: 0.2039 - val_accuracy: 0.9273 - val_loss: 0.2091 - learning_rate: 0.0010
# Epoch 10/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 547ms/step - accuracy: 0.9615 - loss: 0.1267 - val_accuracy: 0.9455 - val_loss: 0.1789 - learning_rate: 0.0010
# Epoch 11/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 547ms/step - accuracy: 0.9562 - loss: 0.1678 - val_accuracy: 0.8909 - val_loss: 0.2208 - learning_rate: 0.0010
# Epoch 12/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 0.9541 - loss: 0.1325 - val_accuracy: 0.9455 - val_loss: 0.1511 - learning_rate: 0.0010
# Epoch 13/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 600ms/step - accuracy: 0.9489 - loss: 0.1247 - val_accuracy: 0.9182 - val_loss: 0.1794 - learning_rate: 0.0010
# Epoch 14/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 557ms/step - accuracy: 0.9538 - loss: 0.1073 - val_accuracy: 0.9455 - val_loss: 0.1505 - learning_rate: 0.0010
# Epoch 15/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 548ms/step - accuracy: 0.9599 - loss: 0.1033 - val_accuracy: 0.9182 - val_loss: 0.1894 - learning_rate: 0.0010
# Epoch 16/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 558ms/step - accuracy: 0.9904 - loss: 0.0623 - val_accuracy: 0.9364 - val_loss: 0.1668 - learning_rate: 0.0010
# Epoch 17/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 573ms/step - accuracy: 0.9778 - loss: 0.0653 - val_accuracy: 0.9455 - val_loss: 0.1694 - learning_rate: 0.0010
# Epoch 18/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 554ms/step - accuracy: 0.9816 - loss: 0.0735 - val_accuracy: 0.8727 - val_loss: 0.3300 - learning_rate: 0.0010
# Epoch 19/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 562ms/step - accuracy: 0.9490 - loss: 0.1454 - val_accuracy: 0.9091 - val_loss: 0.1919 - learning_rate: 0.0010
# Epoch 20/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 0.9724 - loss: 0.0659 - val_accuracy: 0.9455 - val_loss: 0.1497 - learning_rate: 0.0010
# Epoch 21/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 600ms/step - accuracy: 0.9896 - loss: 0.0409 - val_accuracy: 0.9545 - val_loss: 0.1497 - learning_rate: 5.0000e-04
# Epoch 22/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 555ms/step - accuracy: 0.9797 - loss: 0.0507 - val_accuracy: 0.9545 - val_loss: 0.1286 - learning_rate: 5.0000e-04
# Epoch 23/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 559ms/step - accuracy: 0.9859 - loss: 0.0430 - val_accuracy: 0.9545 - val_loss: 0.1362 - learning_rate: 5.0000e-04
# Epoch 24/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 548ms/step - accuracy: 0.9864 - loss: 0.0311 - val_accuracy: 0.9636 - val_loss: 0.1308 - learning_rate: 5.0000e-04
# Epoch 25/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 599ms/step - accuracy: 0.9893 - loss: 0.0284 - val_accuracy: 0.9545 - val_loss: 0.1282 - learning_rate: 5.0000e-04
# Epoch 26/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 0.9938 - loss: 0.0226 - val_accuracy: 0.9636 - val_loss: 0.1441 - learning_rate: 5.0000e-04
# Epoch 27/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 549ms/step - accuracy: 0.9966 - loss: 0.0245 - val_accuracy: 0.9636 - val_loss: 0.1459 - learning_rate: 5.0000e-04
# Epoch 28/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 0.9957 - loss: 0.0238 - val_accuracy: 0.9455 - val_loss: 0.1735 - learning_rate: 5.0000e-04
# Epoch 29/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 597ms/step - accuracy: 0.9691 - loss: 0.0809 - val_accuracy: 0.9273 - val_loss: 0.2273 - learning_rate: 5.0000e-04
# Epoch 30/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 546ms/step - accuracy: 0.9710 - loss: 0.0685 - val_accuracy: 0.9455 - val_loss: 0.1427 - learning_rate: 5.0000e-04
# Epoch 31/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 0.9849 - loss: 0.0414 - val_accuracy: 0.9636 - val_loss: 0.1546 - learning_rate: 5.0000e-04
# Epoch 32/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 549ms/step - accuracy: 0.9952 - loss: 0.0318 - val_accuracy: 0.9636 - val_loss: 0.1526 - learning_rate: 5.0000e-04
# Epoch 33/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 555ms/step - accuracy: 0.9949 - loss: 0.0179 - val_accuracy: 0.9545 - val_loss: 0.1546 - learning_rate: 5.0000e-04
# Epoch 34/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 0.9946 - loss: 0.0223 - val_accuracy: 0.9636 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 35/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 0.9858 - loss: 0.0374 - val_accuracy: 0.9636 - val_loss: 0.1629 - learning_rate: 2.5000e-04
# Epoch 36/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 557ms/step - accuracy: 0.9985 - loss: 0.0210 - val_accuracy: 0.9636 - val_loss: 0.1613 - learning_rate: 2.5000e-04
# Epoch 37/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 600ms/step - accuracy: 0.9988 - loss: 0.0106 - val_accuracy: 0.9636 - val_loss: 0.1590 - learning_rate: 2.5000e-04
# Epoch 38/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 0.9994 - loss: 0.0149 - val_accuracy: 0.9636 - val_loss: 0.1662 - learning_rate: 2.5000e-04
# Epoch 39/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - accuracy: 0.9992 - loss: 0.0166 - val_accuracy: 0.9636 - val_loss: 0.1568 - learning_rate: 2.5000e-04
# Epoch 40/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 551ms/step - accuracy: 0.9949 - loss: 0.0117 - val_accuracy: 0.9636 - val_loss: 0.1670 - learning_rate: 2.5000e-04
# Epoch 41/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 607ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9545 - val_loss: 0.1649 - learning_rate: 2.5000e-04
# Epoch 42/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 0.9636 - val_loss: 0.1683 - learning_rate: 2.5000e-04
# Epoch 43/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 559ms/step - accuracy: 0.9994 - loss: 0.0098 - val_accuracy: 0.9545 - val_loss: 0.1703 - learning_rate: 2.5000e-04
# Epoch 44/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 552ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9636 - val_loss: 0.1627 - learning_rate: 2.5000e-04
# Epoch 45/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 598ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9636 - val_loss: 0.1646 - learning_rate: 1.2500e-04
# Epoch 46/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 551ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9636 - val_loss: 0.1658 - learning_rate: 1.2500e-04
# Epoch 47/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 551ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9636 - val_loss: 0.1674 - learning_rate: 1.2500e-04
# Epoch 48/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 552ms/step - accuracy: 0.9992 - loss: 0.0077 - val_accuracy: 0.9636 - val_loss: 0.1687 - learning_rate: 1.2500e-04
# Epoch 49/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 601ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9636 - val_loss: 0.1658 - learning_rate: 1.2500e-04
# Epoch 50/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9636 - val_loss: 0.1684 - learning_rate: 1.2500e-04
# Epoch 51/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 553ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9636 - val_loss: 0.1690 - learning_rate: 1.2500e-04
# Epoch 52/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 554ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9636 - val_loss: 0.1682 - learning_rate: 1.2500e-04
# Epoch 53/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 603ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9636 - val_loss: 0.1668 - learning_rate: 1.2500e-04
# Epoch 54/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 552ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.9636 - val_loss: 0.1676 - learning_rate: 1.2500e-04
# Epoch 55/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 560ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.9636 - val_loss: 0.1659 - learning_rate: 6.2500e-05
# Epoch 56/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 571ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9636 - val_loss: 0.1668 - learning_rate: 6.2500e-05
# Epoch 57/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 602ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9636 - val_loss: 0.1675 - learning_rate: 6.2500e-05
# Epoch 58/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 558ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9636 - val_loss: 0.1687 - learning_rate: 6.2500e-05
# Epoch 59/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 559ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9636 - val_loss: 0.1681 - learning_rate: 6.2500e-05
# Epoch 60/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9636 - val_loss: 0.1680 - learning_rate: 6.2500e-05
# Epoch 61/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 596ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9636 - val_loss: 0.1691 - learning_rate: 6.2500e-05
# Epoch 62/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9636 - val_loss: 0.1712 - learning_rate: 6.2500e-05
# Epoch 63/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 559ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9636 - val_loss: 0.1737 - learning_rate: 6.2500e-05
# Epoch 64/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 603ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9636 - val_loss: 0.1731 - learning_rate: 6.2500e-05
# Epoch 65/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 556ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9636 - val_loss: 0.1735 - learning_rate: 3.1250e-05
# Epoch 66/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 563ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9636 - val_loss: 0.1739 - learning_rate: 3.1250e-05
# Epoch 67/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 562ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9636 - val_loss: 0.1737 - learning_rate: 3.1250e-05
# Epoch 68/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 611ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9636 - val_loss: 0.1739 - learning_rate: 3.1250e-05
# Epoch 69/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 557ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9636 - val_loss: 0.1727 - learning_rate: 3.1250e-05
# Epoch 70/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 559ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9636 - val_loss: 0.1717 - learning_rate: 3.1250e-05
# Epoch 71/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 558ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9636 - val_loss: 0.1718 - learning_rate: 3.1250e-05
# Epoch 72/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 594ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9636 - val_loss: 0.1721 - learning_rate: 3.1250e-05
# Epoch 73/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 600ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9636 - val_loss: 0.1738 - learning_rate: 3.1250e-05
# Epoch 74/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 560ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9636 - val_loss: 0.1745 - learning_rate: 3.1250e-05
# Epoch 75/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 559ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9636 - val_loss: 0.1770 - learning_rate: 1.5625e-05
